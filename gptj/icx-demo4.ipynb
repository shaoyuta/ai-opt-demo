# %% [markdown]
# - Env:
#     - ```ICX```
#     - pt-39-4
#     - run_generation_ipex_llm.py
#
# Demo:
# - run_generation.py (old version: from  https://github.com/intel-innersource/frameworks.ai.nlp-toolkit.intel-nlp-toolkit:17208550b3010068aaacefe77 )
# - run_generation_ipex_llm.py (new version: from https://github.com/intel-innersource/frameworks.ai.pytorch.ipex-cpu: 84214bdceb7042bbf48610aa1d5f1cc9490d7fe4)
# - Note: new version can use transformer==4.31 but not sandbox version.
# - old version:
# ```
#  ---------- Summary: ----------
# Inference latency: 6.291 sec.
# First token average latency: 0.564 sec.
# Average 2... latency: 0.185 sec.
# P90 2... latency: 0.309 sec.
# P99 2... latency: 0.494 sec.
# ```
# - new version
# ```
#  ---------- Summary: ----------
# Inference latency: 2.849 sec.
# First token average latency: 0.316 sec.
# Average 2... latency: 0.082 sec.
# P90 2... latency: 0.090 sec.
# P99 2... latency: 0.096 sec.
# ```

# %%
# !python run_generation.py --device cpu --input-tokens=32 --max-new-tokens 32 \
    --num-iter=15 --num-warmup=5 --batch-size=1 -m EleutherAI/gpt-j-6b \
    --jit --ipex --token-latency --dtype bfloat16 2>/dev/null
# Out:
# Namespace(model_id='EleutherAI/gpt-j-6b', device='cpu', dtype='bfloat16', input_tokens='32', max_new_tokens=32, prompt=None, greedy=False, ipex=True, ipex_tpp=False, jit=True, num_iter=15, num_warmup=5, batch_size=1, token_latency=True, enable_xpu_optimize=False)
# ---- Prompt size: 32
# past_lenght: tensor([0])
# past_lenght: tensor([0])
# past_lenght: tensor([0])
# ['Once upon a time, there existed a little girl, who liked to have adventures. She wanted to go to places and meet new people, and have fun. One day, she decided to go on an adventure. She packed her bags, and set off on her journey.\n\nThe little girl walked and walked,'] [32]
# Iteration: 0, Time: 39.617159 sec
# ['Once upon a time, there existed a little girl, who liked to have adventures. She wanted to go to places and meet new people, and have fun. One day, she decided to go on an adventure. She packed her bags, and set off on her journey.\n\nThe little girl walked and walked,'] [32]
# ...

# %%
# !python run_generation_ipex_llm.py --device cpu --benchmark --input-tokens=32 --max-new-tokens 32 \
    --num-iter=15 --num-warmup=5 --batch-size=1 -m EleutherAI/gpt-j-6b \
    --jit --ipex --token-latency --dtype bfloat16
# Out:
# Namespace(model_id='EleutherAI/gpt-j-6b', device='cpu', dtype='bfloat16', input_tokens='32', max_new_tokens=32, prompt=None, greedy=False, ipex=True, jit=True, profile=False, benchmark=True, lambada=False, dataset='lambada', accuracy_only=False, num_iter=15, num_warmup=5, batch_size=1, token_latency=True)
# /home/taosy/repo/pytorch/vision/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: ''If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /home/taosy/repo/intel-innersource/ipex-cpu-llm/intel_extension_for_pytorch/frontend.py:453: UserWarning: Conv BatchNorm folding failed during the optimize process.
#   warnings.warn(
# ...
